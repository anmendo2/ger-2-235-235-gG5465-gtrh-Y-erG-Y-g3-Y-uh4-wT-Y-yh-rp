# %%
#pip install jupyterlab

# %%
#pip install ipywidgets

# %%
#pip install voila

# %%
#pip install qrcode[pil]

# %%
#pip install pillow

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# Zona común donde se mostrarán todas las preguntas
pantalla = widgets.Output()

def mostrar_inicio():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('imagen1.jpg');
            background-size: cover;
            background-position: center 25%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.5);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h2>❤️ 3 años contigo ❤️</h2>
            <p>
              Ya 3 increibles años a tu lado 🎉<br>
              Han pasado <b>1096 días</b> desde que estamos juntos, muchos momentos, risas, llantos, enojos pero sobre todo mucho amor.<br>
              Asi que hoy, vengo a que recuerdes un poquito de todo lo vivido, de forma divertida siu 😜
            </p>
          </div>
        </div>
        """))

        boton_inicio = widgets.Button(description="Empezar 🤭", button_style='success')
        boton_inicio.on_click(lambda b: mostrar_pregunta1())
        display(boton_inicio)

# Ejecutar
display(pantalla)
mostrar_inicio()
# Out:
# Output()

# %%
def mostrar_pregunta1():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe1.jpg');
            background-size: cover 80% auto;
            background-position: center 55%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>
        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 1</h3>
            <p>¿Dónde nos conocimos? 💑</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "En marte",
                "En la fiesta de mi ex",
                "En el ballet",
                "En el cole"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "En el ballet":
                mostrar_pregunta2()  # Transición directa
            else:
                feedback.value = "<p style='color:red;'>❌ Nada que ver jaja</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem1.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta2():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe2.jpg');
            background-size: cover 70%;
            background-position: center 35%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>
        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 2</h3>
            <p>¿Cuál fue nuestra primera salida como novios? 🤨</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=["Baile + anticucho", "Desayunito en Creatio", "Fiesta", "Cena en tu casa"],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Baile + anticucho":
                mostrar_pregunta3()  # <-- Asegúrate de definir esta función antes de ejecutar
            else:
                feedback.value = "<p style='color:red;'>❌ Alguien ya no se acuerda</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem2.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta3():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe3.jpg');
            background-size: cover;
            background-position: center;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 3</h3>
            <p>¿Dónde fue nuestro primer beso? 👄</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "En las canchas del cole",
                "En Malnova",
                "En tu auto(de Jade)",
                "En cumple de dulce"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "En Malnova":
                mostrar_pregunta4()  # cambio directo (sin esperar)
            else:
                feedback.value = "<p style='color:red;'>❌ Ese fue con mi ex no confundas 😅</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem3.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta4():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe4.jpg');
            background-size: cover;
            background-position: center;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 4</h3>
            <p>¿Qué día de la semana fue nuestra primera cita? 📅</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=["Lunes", "Sábado", "Martes", "Jueves"],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Jueves":
                mostrar_pregunta5()  # transición directa a la siguiente pregunta
            else:
                feedback.value = "<p style='color:red;'>❌ Con quien habras salido ese dia 😡</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem4.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta5():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe5.jpg');
            background-size: cover;
            background-position: center;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 5</h3>
            <p>¿Qué serie no terminamos? 🍿</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "El juego del camalar",
                "La reina del flow",
                "Suits",
                "Los 100"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Suits":
                mostrar_pregunta6()  # Transición inmediata
            else:
                feedback.value = "<p style='color:red;'>❌ Pff ya supera la reina del flow</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem5.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)

        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta6():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe6.jpg');
            background-size: cover;
            background-position: center 20%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 6</h3>
            <p>¿Dónde fue nuestro primer vije? ✈️</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "Tarija",
                "Potosi",
                "Santa Cruz",
                "Paris"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Tarija":
                mostrar_pregunta7()  # Transición directa
            else:
                feedback.value = "<p style='color:red;'>❌ No ando muy seguro ojala y no te equivoques esta y sea la que pienso jaja</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem6.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)

        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta7():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe7.jpg');
            background-size: 60% ;
            background-position: center 60%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 7</h3>
            <p>¿Qué me enamoro de ti fisicamente? 😏😏</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "Nalgas",
                "Bigote",
                "Sonrisa",
                "Chichis"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Sonrisa":
                mostrar_pregunta8()  # Avanza directo sin esperar
            else:
                feedback.value = "<p style='color:red;'>❌ Obvio que me encanta pero me refiero a lo primero que te dije que me enamoro</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem7.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta8():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe8.jpg');
            background-size: 80%;
            background-position: center;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 8</h3>
            <p>¿Cuál es mi artista top?</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "Adele",
                "Bad Bunny",
                "Tú",
                "Rels B"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Rels B":
                mostrar_pregunta9()  # Salta directo a la siguiente
            else:
                feedback.value = "<p style='color:red;'>❌ Si tambien eres tú pero me refiero a uno famoso jsjsj</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem8.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
def mostrar_pregunta9():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe9.jpg');
            background-size: cover 65%;
            background-position: center 35%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 9</h3>
            <p>¿Cuál es nuestra comida iconica? 😋</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "Sushi",
                "Kingdom",
                "Pizza",
                "Hamburguesa"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Kingdom":
                mostrar_pregunta10()  # Ir directamente a la siguiente
            else:
                feedback.value = "<p style='color:red;'>❌ No manches ya no comeremos nada</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem9.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)

# %%
from IPython.display import HTML, display, clear_output
import ipywidgets as widgets

def mostrar_pregunta10():
    with pantalla:
        clear_output()

        display(HTML("""
        <style>
        #fondo {
            background-image: url('pe10.jpg');
            background-size: 70%;
            background-position: center 35%;
            background-repeat: no-repeat;
            height: 100vh;
            width: 100%;
            display: flex;
            align-items: center;
            justify-content: center;
        }
        #contenedor {
            background-color: rgba(255, 255, 255, 0.6);
            padding: 30px;
            border-radius: 20px;
            max-width: 600px;
            width: 90%;
            text-align: center;
            font-family: 'Segoe UI', sans-serif;
            box-shadow: 0 0 10px rgba(0,0,0,0.3);
        }
        </style>

        <div id="fondo">
          <div id="contenedor">
            <h3>📝 Pregunta 10</h3>
            <p>¿Qué nos depara el futuro? 🤔</p>
          </div>
        </div>
        """))

        opciones = widgets.RadioButtons(
            options=[
                "Una pelea por quien lava los platos",
                "Adoptar un gato",
                "Lo que sea pero juntos",
                "Comer un Kingdom"
            ],
            layout={'width': 'max-content'}
        )

        feedback = widgets.HTML()
        imagen_error = widgets.Output()
        boton = widgets.Button(description="Responder ✅", button_style='success')

        def validar_respuesta(b):
            feedback.value = ""
            imagen_error.clear_output()

            if opciones.value == "Lo que sea pero juntos":
                with pantalla:
                    clear_output()

                    boton_siguiente = widgets.Button(
                        description="Siguiente ▶️",
                        button_style='info'
                    )

                    def mostrar_mensaje_final(b):
                        with pantalla:
                            clear_output()
                            display(HTML("""
                            <style>
                            #fondo-final {
                                background-image: url('msj.jpg');
                                background-size: cover;
                                background-position: center;
                                background-repeat: no-repeat;
                                height: 100vh;
                                width: 100%;
                                display: flex;
                                align-items: center;
                                justify-content: center;
                            }
                            #contenedor-final {
                                background-color: rgba(255, 255, 255, 0.75);
                                padding: 40px;
                                border-radius: 20px;
                                max-width: 850px;
                                width: 90%;
                                text-align: center;
                                font-family: 'Segoe UI', sans-serif;
                                box-shadow: 0 0 15px rgba(0,0,0,0.4);
                                margin: 20px auto;
                            }
                            #contenedor-final h2 {
                                margin-top: 0;
                                color: #d23669;
                                font-size: 28px;
                            }
                            #contenedor-final .mensaje {
                                font-size: 16px;
                                text-align: left;
                                line-height: 1.5;
                                font-weight: bold;
                                column-count: 2;
                                column-gap: 40px;
                            }
                            .audio-secreto {
                                position: absolute;
                                bottom: 10px;
                                left: 10px;
                                width: 1px;
                                height: 1px;
                                opacity: 0;
                            }
                            @media (max-width: 768px) {
                                #contenedor-final .mensaje {
                                    column-count: 1;
                                }
                            }
                            </style>

                            <div id="fondo-final">
                                <div id="contenedor-final">
                                    <h2>¡FELICES 3 AÑOS MI PRINCESA HERMOSA!</h2>
                                    <div class="mensaje">
                                        <b>Increíble pero cierto mi pequeña, hoy se cumplen 3 añitos junto a ti, 3 añitos en los que mi vida cambió completamente, todo para hacerla mejor. Conocerte fue algo increíble aunque no lo noté al principio jeje, pero estar contigo volvió todo lleno de magia y llenó mi vida de colores.</b>
                                        <b>Cada momento juntitos, el primer beso, nuestro primer kingdom, la primera vez que fui a tu casa, cada cita en el parque, un increíble 15 de abril, cuando aprendiste a manejar bici, nuestro primer viaje, o el segundo, o el tercero... son tantas cosas que no pararía de escribir nunca mi bebé.</b>
                                        <b>Sí, aunque hubieron peleas, discusiones y momentos no tan lindos, sé que nosotros somos mucho más que eso. En la pregunta de "lo que sea pero juntos", sabes que no me importa si es aquí o en otro país, con dinero o sin dinero.</b>
                                        <b>No me importa qué haya en el futuro mientras sea contigo, porque sé que juntos podremos superar cada obstáculo que se nos presente. Y sabes qué, los loquitos flaquitos hoy cumplen 3 años demostrando a todos los que no nos quisieron juntos que sí podemos.</b>
                                        <b>Que tú y yo estamos hechos para estar juntos. No hay nada más, tú y yo. Yo hoy tomo mi decisión de que quiero estar contigo el resto de mi vida, no me importa nadie más.</b>
                                        <b>Hoy te elijo a ti para no cambiarte nunca más. Me haces mejor persona, me haces feliz, me completas. Así que lo siento pero te elijo definitivamente y ya no puedes irte, no permito que te vayas.</b>
                                        <b>Estás condenada a una vida junto a mí pase lo que pase, porque te amo, te amo incondicionalmente, te amo con locura y con todo mi ser. Perdón por todos los momentos malos, prometo luchar porque cada vez sean menos.</b>
                                        <b>Siempre hay tropezones, pero te prometo que tú y yo, somos para siempre. Espero te haya gustado todo esto que fue algo de locos, me estresé mucho jajs pero lo superé porque tú me estresas más e igual te aguanto siu.</b>
                                        <b>Te amo mi princesa, felices 1096 días mi preciosa, te amo hasta el infinito y más allá. 💖</b>
                                    </div>
                                </div>

                                <iframe class="audio-secreto"
                                    src="https://www.youtube.com/embed/-MDyMV3Y6Eg?autoplay=1&loop=1&playlist=-MDyMV3Y6Eg"
                                    frameborder="0"
                                    allow="autoplay">
                                </iframe>
                            </div>
                            """))

                    boton_siguiente.on_click(mostrar_mensaje_final)

                    display(HTML("""
                  <div style='text-align:center; padding: 20px; font-family:Segoe UI, sans-serif;'>
                        <h2>Gracias por tantos momentos juntos 💖</h2>
                        <iframe width="560" height="315"
                        src="https://www.youtube.com/embed/eEisqYJL9js?autoplay=1"
                        frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>
                    </div>
                    """))

                    display(boton_siguiente)

            else:
                feedback.value = "<p style='color:red;'>❌ Lo del gato antes muerto que perder la vida por un gato, lo demas si tambien nosotros jaja</p>"
                with imagen_error:
                    display(widgets.Image(value=open("mem10.jpg", "rb").read(), format='jpg', width=300))

        boton.on_click(validar_respuesta)
        display(opciones, boton, feedback, imagen_error)
